# %%
print("raajan")
# Out:
# raajan

# %%
a = 8
counter = 0
count = 0
while counter <= a:
    count = (count + 1)
    counter = (counter + 1)

print(count)
print(counter)
# Out:
# 9
# 9

# %%
a = 8
i = 6
count = 1
while i <= a:
    if (i % 2) == 1:
        count += 1
    i = (i + 1)
print(count)
# Out:
# 2

# %%
a=4
b=7
counter=0
sum=0
while counter<3:
    sum=(sum+a+b)
    a=a+1
    b=b+1
    counter=counter+1
print(sum)
# Out:
# 39

# %%
a = 3
while a > 0:
    print(a + 1)
    a = a - 1
# Out:
# 4
# 3
# 2
