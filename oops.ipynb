# %%
## class --class is a blue print or templete
## class contain variables and methods 

class student:
    name="raju"

    def display(self):
        print(f"name of the student:",self.name)

# %%
## object
## it is real entity created by the class

class student:
    name="raajan"

    def display(self):
        print(f"student name is :",self.name)

# %%
##object creation
std=student()

# %%
std.display()
# Out:
# student name is : raajan

# %%
## constructor
## when the object created it is automatically crated

class students:

    def __init__(self,name,age):
        self.name=name
        self.age=age

    def display(self):
        print(f"name of the student:",self.name)
        print(f"age of the student :",self.age)

# %%
##obj created
std1=students("raju",24)
std2=students("raajan",25)

# %%
std1.display()
# Out:
# name of the student: raju
# age of the student : 24

# %%
std2.display()
# Out:
# name of the student: raajan
# age of the student : 25

# %%
## attributes of an object
## accessing the attributes(like name,age)

class employee:

    def __init__(self,name,company):
        self.name=name
        self.company=company
    def get_name(self):
        print(f"name of the employee:",self.name)
    def get_company(self):
        print(f"name of the company:",self.company)

# %%
## obj created
emp1=employee("virat","ind-cric")
emp2=employee("nanna","farmer")

# %%
emp2.get_name()
emp2.get_company()
# Out:
# name of the employee: nanna
# name of the company: farmer

# %%
print(emp1.name)
print(emp1.company)
# Out:
# virat
# ind-cric

# %%
## updating the attribute

class student:
    def __init__(self,name,college):
        self.name=name
        self.college=college
    def display(self):
        print(f"name of the std:",self.name)
        print(f"name of the college:",self.college)
    def update_name_col(self,name,college):
        self.name=name
        self.college=college
    def update_name(self,name):
        self.name=name
    def update_col(self,college):
        self.college=college

# %%
std11=student("talari raju","ap.model college")
std22=student("talari janardhan","parimala vidyanikethan")

# %%
std11.display()
# Out:
# name of the std: talari raju
# name of the college: ap.model college

# %%
std22.display()
# Out:
# name of the std: talari janardhan
# name of the college: parimala vidyanikethan

# %%
std11.update_name_col("raajan","sv.university")

# %%
std11.display()
# Out:
# name of the std: raajan
# name of the college: sv.university

# %%
std22.update_col("IIIT-SRIKAKULAM")

# %%
std22.display()
# Out:
# name of the std: talari janardhan
# name of the college: IIIT-SRIKAKULAM

# %%
## instance attributes
## each instance attribute have different value of objects
## these are created by constructor or through self

class market:
    def __init__(self,name,place):
        self.name=name
        self.place=place

# %%
mart=market("super-market","bajar-street")
mart1=market("D-mart","balaji-colony")

# %%
print(mart.name)
print(mart1.name)
# Out:
# super-market
# D-mart

# %%
## class attributes
## each class attributes have same value attribute of object
## it was declare through the constructor of the class

class employee:
    company="infosys"

    def __init__(self,name,hire_year):
        self.name=name
        self.hire_year=hire_year

# %%
emp1=employee("raju",2026)
emp2=employee("raajan",2027)

# %%
print(emp1.company)
print(emp2.company)
# Out:
# infosys
# infosys

# %%
## static attributes--used as class attribute
## there is no keyword called static attribute
## this is not depend on object and store the data

class student:
    college="sv.university"

# %%
std1=student()
std2=student()

# %%
print(student.college)
print(std1.college)
print(std2.college)
# Out:
# sv.university
# sv.university
# sv.university

# %%
## instance VS class  attributes
class student:
    college="sv.university"                   ## class attribute

    def __init__(self,name,graduation):
        self.name=name                       ## instance attribute
        self.graduation=graduation

# %%
std1=student("raju","msc-statistics")
std2=student("jaswanth","msc-applied")

# %%
## instance attributes
print(std1.graduation)
print(std2.graduation)
# Out:
# msc-statistics
# msc-applied

# %%
## class attributes
print(std1.college)
print(std2.college)
# Out:
# sv.university
# sv.university

# %%
## instance method
## it work with the specific object
## it can access and modify the instance attributes using self parameter

class cart:
    def __init__(self):
        self.items={}
    def add_items(self,item_name,quantity):
        self.items[item_name]=quantity
        self.display()##------------------------------instance method apply amd accessed here
    def display(self):
        print(self.items)

# %%
c11=cart()

# %%
## run and display the output without c11.display()
c11.add_items("banana",3)
c11.add_items("strawberry",25)
# Out:
# {'banana': 3}
# {'banana': 3, 'strawberry': 25}

# %%
## this is unnecessary while we doing with instance method
c11.display()
# Out:
# {'banana': 3, 'strawberry': 25}

# %%
## class method
##  method work with the class level data (class attributes) not instance attributes
## it uses the decorator (@classmethod) and receives the cls as 1st parameter
## it does not depend on object

class cart:
    flat_discount=0
    @classmethod
    def update_discount(cls,new_discount):
        cls.flat_discount=new_discount

# %%
cart.update_discount(222)

# %%
cart.flat_discount
# Out:
# 222

# %%
## multiple class methods

class cart:
    flat_discount=0
    @classmethod
    def update_discount(cls,new_discount):
        cls.flat_discount=new_discount
        ## Another class method for increment the discount 
    @classmethod
    def increment_discount(cls,amount):
        new_discount=cls.flat_discount+amount
        cls.update_discount(new_discount)

# %%
## without object and instances
cart.update_discount(250)

# %%
cart.flat_discount
# Out:
# 250

# %%
cart.increment_discount(250)

# %%
cart.flat_discount
# Out:
# 500

# %%
## static method 
## this method not access the both instance and class data
## it behave like a normal function but placed inside a class for logocal grouping
# this method uses the @staticmethod decorator

class cart:
    @staticmethod
    def greet():
        print(f"hi buchi how are you")

# %%
cart.greet()
# Out:
# hi buchi how are you

# %%
class calculator:
    @staticmethod
    def add(a,b):
        return a+b

# %%
print(calculator.add(2,4))
# Out:
# 6

# %%
## instance VS class VS static
class employee:
    company="google"

    def __init__(self,name):
        self.name=name

    def show_name(self):
        print(f"name of the employee:",self.name)
    @classmethod
    def show_company(cls):
        print(f"company name:",cls.company)

    @staticmethod
    def greet(employee):
        print(f"welcome: Mr.",employee.name)

# %%
emp=employee("raajan")
emp.show_name()
emp.show_company()
employee.greet(emp)
# Out:
# name of the employee: raajan
# company name: google
# welcome: Mr. raajan

# %%
## Challenge=1

class movie:
    def __init__(self,title,director,year,rating):
        self.title=title
        self.director=director
        self.year=year
        self.rating=rating

    def display_info(self):
        print(f"movie name:{self.title}")
        print(f" director name:{self.director}")
        print(f"year of the release:{self.year}")
        print(f"rating of the movie:{self.rating}")

    def updating_rating(self,increase):
        self.rating+=increase
        print(f"{self.title} is getting rate of {self.rating}")

    def is_classic(self):
        if self.year<2000:
            print("True")
        else:
            print("False")

# %%
movie1=movie("raajan","raju",2020,8.8)
movie2=movie("RCB","DK",2025,10.0)

# %%
movie1.display_info()
# Out:
# movie name:raajan
#  director name:raju
# year of the release:2020
# rating of the movie:8.8

# %%
movie2.display_info()
# Out:
# movie name:RCB
#  director name:DK
# year of the release:2025
# rating of the movie:10.0

# %%
movie1.updating_rating(5)
# Out:
# raajan is getting rate of 13.8

# %%
class library:
    def __init__(self):
        self.books={}
    def add_books(self,book_name,author,publisher,pen_name,published_year):
        self.books[book_name]={
            "author":author,
            "publisher":publisher,
            "pen_name":pen_name,
            "published_year":published_year
            }
    def display_books(self):
        for book_name,details in self.books.items():
            print(f"the book name is:{book_name}")
            print(f"the author name is:{details['author']}")
            print(f"the publisher is:{details['publisher']}")
            print(f"the pen name is:{details['pen_name']}")
            print(f"published year is:{details['published_year']}")
            print()

    def remove_books(self,book_name):
        if book_name in self.books:
            del self.books[book_name]
            print(f"{book_name} removed successfully")
        else:
            print(f"book not found")

    def update_books(self,book_name,author,publisher,pen_name,published_year):
        if book_name in self.books:
            self.books[book_name]["author"]=author
            self.books[book_name]["publisher"]=publisher
            self.books[book_name]["pen_name"]=pen_name
            self.books[book_name]["published_year"]=published_year
            print(f"successfully updated")
        else:
            print(f"book not found")

    def find_books(self,book_name):
        if book_name in self.books:
            self.books[book_name]
            print(f"{book_name} found successfully")
        else:
            print(f"book not found")

    def replace_books(self,old_book,new_book):
        if old_book in self.books:
            self.books[new_book]=self.books.pop(old_book)
            print(f"{old_book} is successfully replaced with {new_book}")
        else:
            print(f"book not found")

# %%
lib=library()

# %%
lib.add_books("geethanjali","tagoor","roopa","anjali",1999)
lib.add_books("ramayanam","valmiki","garuda","anjana",1888)
lib.add_books("bharatham","veda vyasa","vyasa","krish",1777)

# %%
lib.display_books()
# Out:
# the book name is:geethanjali
# the author name is:tagoor
# the publisher is:roopa
# the pen name is:anjali
# published year is:1999
#
# the book name is:ramayanam
# the author name is:valmiki
# the publisher is:garuda
# the pen name is:anjana
# published year is:1888
#
# the book name is:bharatham
# the author name is:veda vyasa
# the publisher is:vyasa
# the pen name is:krish
# published year is:1777

# %%
lib.remove_books("maha")
# Out:
# book not found

# %%
lib.remove_books("bharatham")
# Out:
# bharatham removed successfully

# %%
lib.display_books()
# Out:
# the book name is:geethanjali
# the author name is:tagoor
# the publisher is:roopa
# the pen name is:anjali
# published year is:1999
#
# the book name is:ramayanam
# the author name is:valmiki
# the publisher is:garuda
# the pen name is:anjana
# published year is:1888

# %%
lib.update_books("ramayanam","valmiki","anjana","garudaa","400bc")
# Out:
# successfully updated

# %%
lib.display_books()
# Out:
# the book name is:geethanjali
# the author name is:tagoor
# the publisher is:roopa
# the pen name is:anjali
# published year is:1999
#
# the book name is:ramayanam
# the author name is:valmiki
# the publisher is:anjana
# the pen name is:garudaa
# published year is:400bc

# %%
lib.find_books("vikatakavi")
# Out:
# book not found

# %%
lib.find_books("ramayanam")
# Out:
# ramayanam found successfully

# %%
lib.replace_books("geethanjali","gora")
# Out:
# geethanjali is successfully replaced with gora

# %%
lib.display_books()
# Out:
# the book name is:ramayanam
# the author name is:valmiki
# the publisher is:anjana
# the pen name is:garudaa
# published year is:400bc
#
# the book name is:gora
# the author name is:tagoor
# the publisher is:roopa
# the pen name is:anjali
# published year is:1999

# %%
class cart:
    def __init__(self):
        self.items={}

    def add_items(self,item_name,brand,quantity,price):
        self.items[item_name]={
            "brand":brand,
            "quantity":quantity,
            "price":price
        }
    def display_items(self):
        for item_name,details in self.items.items():
            print(f"item name:{item_name}")
            print(f"brand name :{details['brand']}")
            print(f"quantity:{details['quantity']}")
            print(f"price of item:{details['price']}")
            print()
        
    def update_items(self,item_name,quantity,brand,price):
       if item_name in self.items:
           self.items[item_name]["brand"]=brand
           self.items[item_name]["quantity"]=quantity
           self.items[item_name]["price"]=price
           print(f"{item_name} updated successfully")
       else:
           print("item not found")
      
    def remove_items(self,item_name):
        if item_name in self.items:
            del self.items[item_name]
            print(f"{item_name} removed successfully")
        else:
            print("item not found")
        
    def search_items(self,item_name):
        if item_name in self.items:
            self.items[item_name]
            print(f"{item_name} search successfully")
        else:
            print("item not found")
            
    def replace_items(self, old_name, new_name):
        if old_name in self.items:
            self.items[new_name] = self.items.pop(old_name)
            print(f"{old_name} replaced with {new_name} successfully")
        else:
            print("Item not found")

# %%
c1=cart()

# %%
c1.add_items("laptop","hp",3,3000)
c1.add_items("mobile","moto",4,4000)

# %%
c1.display_items()
# Out:
# item name:laptop
# brand name :hp
# quantity:3
# price of item:3000
#
# item name:mobile
# brand name :moto
# quantity:4
# price of item:4000

# %%
c1.update_items("laptop","dell",6,6666)
# Out:
# laptop updated successfully

# %%
c1.update_items("watch","rolex",7,7000)
# Out:
# item not found

# %%
c1.search_items("laptop")
# Out:
# laptop search successfully

# %%
c1.search_items("car")
# Out:
# item not found

# %%
c1.display_items()
# Out:
# item name:laptop
# brand name :6
# quantity:dell
# price of item:6666
#
# item name:mobile
# brand name :moto
# quantity:4
# price of item:4000

# %%
c1.replace_items("mobile","fan")
# Out:
# mobile replaced with fan successfully

# %%
c1.display_items()
# Out:
# item name:laptop
# brand name :6
# quantity:dell
# price of item:6666
#
# item name:fan
# brand name :moto
# quantity:4
# price of item:4000

# %%
class bankbalance:
   

    def __init__(self,ac_holder,ac_number,branch,balance):
        self.ac_holder=ac_holder
        self.ac_number=ac_number
        self.branch=branch
        self.balance=balance

    def display(self):
        print(f"account holder name is :",{self.ac_holder})
        print(f"account number of customer:",{self.ac_number})
        print(f"branch of the bank :",{self.branch})
        print(f"bank balance is:",{self.balance})



    def deposite(self,amount):
       
        self.balance+=amount
        print(f"your current balance is :",{self.balance})

    def withdraw(self,amount):
      
        if amount > self.balance:
            print(f"insufficient balance")
        else:
           self.balance -= amount
           print(f"withdraw success")

    def check_balance(self):
        print(f"present balance:",self.balance)

# %%
account1 = bankbalance("talari narasimhulu",123,"kurnool",100000)
account2 = bankbalance("talari lakshmi",456,"mantralayam",50000)
account3 = bankbalance("talari raju",789,"banglore",25000)
account4 = bankbalance("talari thimappa",100,"vizag",10000)

# %%
account1.display()
# Out:
# account holder name is : {'talari narasimhulu'}
# account number of customer: {123}
# branch of the bank : {'kurnool'}
# bank balance is: {100000}

# %%
account1.deposite(11111)
# Out:
# your current balance is : {111111}

# %%
account1.withdraw(111)
# Out:
# withdraw success

# %%
account1.check_balance()
# Out:
# present balance: 111000

# %%
## Challenge=1

class movie:
    def __init__(self,title,director,year,rating):
        self.title=title
        self.director=director
        self.year=year
        self.rating=rating

    def display_info(self):
        print(f"movie name:{self.title}")
        print(f" director name:{self.director}")
        print(f"year of the release:{self.year}")
        print(f"rating of the movie:{self.rating}")

    def updating_rating(self,increase):
        self.rating+=increase
        print(f"{self.title} is getting rate of {self.rating}")

    def is_classic(self):
        if self.year<2000:
            print("True")
        else:
            print("False")

    def will_win_again(self):
        if self.year>2024:
            print(f"yes we will,next sala kooda cup namadeeeeeeeeeee")
        else:
            print(f"better luck next time")

# %%
ipl1=movie("rcb","dk",2025,10)
ipl2=movie("rcb2","dk&mobat",2026,10)

# %%
ipl1.display_info()
# Out:
# movie name:rcb
#  director name:dk
# year of the release:2025
# rating of the movie:10

# %%
ipl2.display_info()
# Out:
# movie name:rcb2
#  director name:dk&mobat
# year of the release:2026
# rating of the movie:10

# %%
ipl1.is_classic()
# Out:
# False

# %%
ipl1.will_win_again()
# Out:
# yes we will,next sala kooda cup namadeeeeeeeeeee

# %%
ipl2.will_win_again()
# Out:
# yes we will,next sala kooda cup namadeeeeeeeeeee
