# %% [markdown]
# ## lambda ia a anonymous function and it is one liner function

# %%
## regural function
def add(a,b):
    return a+b

# %%
print(add(2,5))
# Out:
# 7

# %%
## lambda function
addition=lambda a,b:a+b

# %%
print(addition(2,5))
# Out:
# 7

# %%
square=lambda x:x**2
print(square(3))
print(square(5))
print(square(8))
# Out:
# 9
# 25
# 64

# %%
## lambda with multiple arguments
area=lambda length,breadth:length*breadth
print(area(5,4))
# Out:
# 20

# %%
## lambda with condition
## check if even or odd
is_even=lambda x : "even" if x % 2==0 else "odd"
print(is_even(67))
print(is_even(98))
# Out:
# odd
# even

# %%
is_even(78)
# Out:
# 'even'

# %%
## check negative or positive
is_negative=lambda x:"positive" if x>0 else "negative"
print(is_negative(-4))
print(is_negative(8))
# Out:
# negative
# positive

# %%
## check pass or fail
is_pass=lambda x:"pass" if x>=35 else "fail"
print(is_pass(35))
print(is_pass(87))
print(is_pass(-76))
# Out:
# pass
# pass
# fail

# %%
## check adult or minor
is_minor=lambda x:"minor" if x<=18 else "adult"
print(is_minor(66))
print(is_minor(18))
# Out:
# adult
# minor

# %% [markdown]
# ##  map function with lambda using list of numbers
# ## map function allpy to all elements in a list

# %%
## regular function without lambda
def square(x):
    return x*x
nums=[1,2,3,4,5]
result=list(map(square,nums))
print(result)
# Out:
# [1, 4, 9, 16, 25]

# %%
## using lambda
nums=[2,3,4,5]
result2=list(map(lambda x:x*x,nums))
print(result2)
# Out:
# [4, 9, 16, 25]

# %%
nums=[2,3,4,5]
result2=list(map(lambda x:x*5,nums))
print(result2)
# Out:
# [10, 15, 20, 25]

# %%
## check true or false while using map
nums=[2,3,4,5]
result2=list(map(lambda x:x%2==0,nums))
print(result2)
# Out:
# [True, False, True, False]

# %% [markdown]
# ## filter function apply for only specific conditions in a list

# %%
nums=[2,3,4,5]
result2=list(filter(lambda x:x%2==0,nums))
print(result2)
# Out:
# [2, 4]

# %% [markdown]
# ## using sorted

# %%
students=[("raju",70),("buchi",80),("nanna",90)]
print(sorted(students))
# Out:
# [('buchi', 80), ('nanna', 90), ('raju', 70)]

# %%
result=sorted(students,key=lambda x:x[0])
print(result)
# Out:
# [('buchi', 80), ('nanna', 90), ('raju', 70)]

# %%
employees=[
    ("raju",5000,5),
    ("buchi",4000,4),
    ("nanna",3000,3)
]

# %%
result=sorted(employees,key=lambda x:(x[1],x[2]))
print(result)
# Out:
# [('nanna', 3000, 3), ('buchi', 4000, 4), ('raju', 5000, 5)]

# %%
result2=list(filter(lambda x:x[1]>=6000 and x[2]<=4,employees))
print(result2)
# Out:
# []

# %%
l2=["hello buchi,how are you,iam fine here"]
emp=[]
output=list(map(lambda b:emp.extend(b.split(' '),l2)))
print(emp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 l2=["hello buchi,how are you,iam fine here"]
#       2 emp=[]
# ----> 3 output=list(map(lambda b:emp.extend(b.split(' '),l2)))
#       4 print(emp)
#
# TypeError: map() must have at least two arguments.
